# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.datasets import load_breast_cancer
cancer= load_breast_cancer()
X= cancer.data
y= cancer.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=  train_test_split(X,y, test_size=0.3,random_state=44, shuffle=True)
print('X_train is', X_train.shape)
print('y_train is', y_train.shape)
print('X_test is', X_test.shape)
print('y_test is', y_test.shape)
# Out:
# X_train is (398, 30)
# y_train is (398,)
# X_test is (171, 30)
# y_test is (171,)

# %% [markdown]
# # **Classification**

# %% [markdown]
# ## **How to quickly compare ML models using lazypredict ?**
#  It helps understand which models work better on the problem without any parameter tuning, then you can choose the best five, models, and then apply hyperparameter tuning to them.
# #Install the lazypredict library
# ! pip install lazypredict

# %%
# ! pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# Defines and builds the lazyclassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)

### fitting data in LazyClassifier
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
### lets check which model did better on Breast Cancer Dataset
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 10.06it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# PassiveAggressiveClassifier        0.98  ...        0.03
# LinearSVC                          0.98  ...        0.03
# LogisticRegression                 0.98  ...        0.07
# ExtraTreesClassifier               0.98  ...        0.26
# CalibratedClassifierCV             0.98  ...        0.07
# XGBClassifier                      0.97  ...        0.74
# SVC                                0.96  ...        0.05
# Perceptron                         0.96  ...        0.02
# RandomForestClassifier             0.96  ...        0.38
# LGBMClassifier                     0.96  ...        0.15
# AdaBoostClassifier                 0.96  ...        0.30
# BaggingClassifier                  0.96  ...        0.12
# SGDClassifier                      0.95  ...        0.06
# RidgeClassifier                    0.96  ...        0.04
# ...
