# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Metrics for classification**
#
#
# *   confusion_matrix
# *   roc
# *   auc
# *   zero_one_loss

# %%
# 1. confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score, classification_report,roc_curve

y_true = ['a','d','a','g','a','d']
y_pred = ['a','a','g','g','d','g']

cm= confusion_matrix(y_true, y_pred)
accuracy= accuracy_score(y_true, y_pred)
f1= f1_score(y_true, y_pred, average='micro')
recall= recall_score(y_true, y_pred, average='micro')
precision= precision_score(y_true, y_pred, average='micro')

print(cm)
print('accuracy is',accuracy,'\n f1 is   ', f1,'\n recall is ', recall, '\n precision is ', precision)
print(classification_report(y_true, y_pred ))
# Out:
# [[1 1 1]
#  [1 0 1]
#  [0 0 1]]
# accuracy is 0.3333333333333333
#  f1 is    0.3333333333333333
#  recall is  0.3333333333333333
#  precision is  0.3333333333333333
#               precision    recall  f1-score   support
#
#            a       0.50      0.33      0.40         3
#            d       0.00      0.00      0.00         2
#            g       0.33      1.00      0.50         1
#
#     accuracy                           0.33         6
#    macro avg       0.28      0.44      0.30         6
# weighted avg       0.31      0.33      0.28         6

# %%
# 2. roc & 3. auc
from sklearn.metrics import roc_curve, auc
import numpy as np

y =      np.array([1    , 1     , 2     , 2])
scores = np.array([0.3  , 0.4   ,   0.35, 0.8])
print(y,'\n',scores)

fpr, tpr, thresholds = roc_curve(y, scores, pos_label=2)
print('\n fpr is        ', fpr)
print(' tpr is        ',tpr)
print(' thresholds is ',thresholds)

auc = auc(fpr, tpr)
print('\n AUC: %.2f' % auc)


# plotting
import matplotlib.pyplot as plt

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)
# Out:
# [1 1 2 2]
#  [0.3  0.4  0.35 0.8 ]
#
#  fpr is         [0.  0.  0.5 0.5 1. ]
#  tpr is         [0.  0.5 0.5 1.  1. ]
#  thresholds is  [1.8  0.8  0.4  0.35 0.3 ]
#
#  AUC: 0.75

# %%
# 4. zero one loss
from sklearn.metrics import zero_one_loss

y_pred = [1, 2, 3, 4]
y_true = [2, 2, 3, 4]

zero_one_loss= zero_one_loss(y_true, y_pred)
print('Zero One Loss Value : ', zero_one_loss )
# Out:
# Zero One Loss Value :  0.25

# %% [markdown]
# # **Metrics for regression**
#
#
#
# *   mean_absolute_error (MAE)
# *   mean_squared_error (MSE)
# *   median_absolute_error

# %%
# MAE, MSE,median_absolute_error,root of MAE (RMSE )
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error
y_true = [3, -0.5, 2, 7]
y_pred = [3, 0.0, 2, 7]

print(mean_absolute_error(y_true, y_pred))
print(mean_squared_error(y_true, y_pred))
print(median_absolute_error(y_true, y_pred))

import math 
RMAE = math.sqrt(mean_absolute_error(y_true, y_pred))
print(RMAE)
# Out:
# 0.125
# 0.0625
# 0.0
# 0.3535533905932738
